# %% [markdown]
# ## CIND820 Big Data Analytics Project - Data Mining for Customer Behavior Analysis in Retail Sales

# %%
# import libraries 

import pandas as pd
import numpy as np
import matplotlib as plt

# %%
# import dataset

path = r"C:\Users\jrroz\Desktop\June\TMU\Course Materials\CIND820\Data\Online Retail.xlsx"

df = pd.read_excel(path)

# %% [markdown]
# ### 1. Dataset Inspection

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 541904 2011-12-09 12:50:00       0.85     12680.0  France
# 541905 2011-12-09 12:50:00       2.10     12680.0  France
# 541906 2011-12-09 12:50:00       4.15     12680.0  France
# 541907 2011-12-09 12:50:00       4.15     12680.0  France
# 541908 2011-12-09 12:50:00       4.95     12680.0  France

# %%
# count of unique values

num_rows = df.shape[0]
num_cols = df.shape[1]
num_customers = df['CustomerID'].nunique()
num_products = df['StockCode'].nunique()
num_invoices = df['InvoiceNo'].nunique()
num_countries = df['Country'].nunique()

print(num_rows, num_cols, num_customers, num_products, num_invoices, num_countries)
# Out:
# 541909 8 4372 4070 25900 38

# %%
# check data types 

df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
# change CustomerID data type

df['CustomerID'] = df['CustomerID'].astype("object")

df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID             object
# Country                object
# dtype: object

# %%
# check start and end dates

print(df['InvoiceDate'].min())
print(df['InvoiceDate'].max())
# Out:
# 2010-12-01 08:26:00
# 2011-12-09 12:50:00

# %%
# descriptive statistics for quantitative columns

df[['Quantity', 'UnitPrice']].describe()
# Out:
#             Quantity      UnitPrice
# count  541909.000000  541909.000000
# mean        9.552250       4.611114
# std       218.081158      96.759853
# min    -80995.000000  -11062.060000
# 25%         1.000000       1.250000
# 50%         3.000000       2.080000
# 75%        10.000000       4.130000
# max     80995.000000   38970.000000

# %% [markdown]
# ### 2. Data Quality Check
#
# 2.1 Check for negative UnitPrice and negative Quantity
#
# - 2.1.1 Flag "adjust bad debt" and "cancellations" fields (InvoiceNo starting with "A" and "C" respectively)
#
# - 2.1.2 Identify fields with negative quantities that are not "cancellations"
#
# 2.2 Check for UnitPrice = 0
#
#
# 2.3 Check for missing values
#
# , duplicates, anomalies
# - flag sales with InvoiceNo starting with "A" and "C" (bad debt adjustment and cancellations)?

# %% [markdown]
# #### 2.1 Check for Negative UnitPrice and Quantity

# %%
# negative price check

negative_price = df[df["UnitPrice"] < 0]

negative_price
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice CustomerID         Country  BadDebt  Cancellation  \
# 299983  -11062.06        NaN  United Kingdom     True         False
# 299984  -11062.06        NaN  United Kingdom     True         False
#
#         CustomerID_NA  Description_NA
# 299983           True           False
# 299984           True           False

# %%
# "Adjust bad debt" records

df.loc[df['InvoiceNo'].str.startswith("A", na = False), :]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299982   A563185         B  Adjust bad debt         1 2011-08-12 14:50:00
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice CustomerID         Country  BadDebt  Cancellation  \
# 299982   11062.06        NaN  United Kingdom     True         False
# 299983  -11062.06        NaN  United Kingdom     True         False
# 299984  -11062.06        NaN  United Kingdom     True         False
#
#         CustomerID_NA  Description_NA
# 299982           True           False
# 299983           True           False
# 299984           True           False

# %% [markdown]
# #### 2.1.1 Identify and Flag Cancellations and Bad Debt Adjustments

# %%
# InvoiceNo starting with 'C' indicates cancellation

df.loc[df['InvoiceNo'].str.startswith("C", na = False), :]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice CustomerID         Country  BadDebt  \
# 141    2010-12-01 09:41:00      27.50    14527.0  United Kingdom    False
# 154    2010-12-01 09:49:00       4.65    15311.0  United Kingdom    False
# 235    2010-12-01 10:24:00       1.65    17548.0  United Kingdom    False
# 236    2010-12-01 10:24:00       0.29    17548.0  United Kingdom    False
# 237    2010-12-01 10:24:00       0.29    17548.0  United Kingdom    False
# ...                    ...        ...        ...             ...      ...
# 540449 2011-12-09 09:57:00       0.83    14397.0  United Kingdom    False
# 541541 2011-12-09 10:28:00     224.69    15498.0  United Kingdom    False
# 541715 2011-12-09 11:57:00      10.95    15311.0  United Kingdom    False
# 541716 2011-12-09 11:58:00       1.25    17315.0  United Kingdom    False
# 541717 2011-12-09 11:58:00       1.25    17315.0  United Kingdom    False
#
#         Cancellation  CustomerID_NA  Description_NA
# 141             True          False           False
# 154             True          False           False
# 235             True          False           False
# 236             True          False           False
# 237             True          False           False
# ...              ...            ...             ...
# 540449          True          False           False
# 541541          True          False           False
# 541715          True          False           False
# 541716          True          False           False
# 541717          True          False           False
#
# [9288 rows x 12 columns]

# %%
# check for other InvoiceNo starting with a letter

df.loc[df["InvoiceNo"].str.contains(r"^[A-Za-z]", na=False)]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice CustomerID         Country  BadDebt  \
# 141    2010-12-01 09:41:00      27.50    14527.0  United Kingdom    False
# 154    2010-12-01 09:49:00       4.65    15311.0  United Kingdom    False
# 235    2010-12-01 10:24:00       1.65    17548.0  United Kingdom    False
# 236    2010-12-01 10:24:00       0.29    17548.0  United Kingdom    False
# 237    2010-12-01 10:24:00       0.29    17548.0  United Kingdom    False
# ...                    ...        ...        ...             ...      ...
# 540449 2011-12-09 09:57:00       0.83    14397.0  United Kingdom    False
# 541541 2011-12-09 10:28:00     224.69    15498.0  United Kingdom    False
# 541715 2011-12-09 11:57:00      10.95    15311.0  United Kingdom    False
# 541716 2011-12-09 11:58:00       1.25    17315.0  United Kingdom    False
# 541717 2011-12-09 11:58:00       1.25    17315.0  United Kingdom    False
#
#         Cancellation  CustomerID_NA  Description_NA
# 141             True          False           False
# 154             True          False           False
# 235             True          False           False
# 236             True          False           False
# 237             True          False           False
# ...              ...            ...             ...
# 540449          True          False           False
# 541541          True          False           False
# 541715          True          False           False
# 541716          True          False           False
# 541717          True          False           False
#
# [9291 rows x 12 columns]

# %%
# flag bad debt fields and cancellations

df['BadDebt'] = df['InvoiceNo'].str.contains(r"^A", na=False)
df['Cancellation'] = df['InvoiceNo'].str.contains(r"^C", na=False)

# %%
# negative quantity check

negative_quantity = df[df["Quantity"] < 0]

negative_quantity
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice CustomerID         Country  BadDebt  \
# 141    2010-12-01 09:41:00      27.50    14527.0  United Kingdom    False
# 154    2010-12-01 09:49:00       4.65    15311.0  United Kingdom    False
# 235    2010-12-01 10:24:00       1.65    17548.0  United Kingdom    False
# 236    2010-12-01 10:24:00       0.29    17548.0  United Kingdom    False
# 237    2010-12-01 10:24:00       0.29    17548.0  United Kingdom    False
# ...                    ...        ...        ...             ...      ...
# 540449 2011-12-09 09:57:00       0.83    14397.0  United Kingdom    False
# 541541 2011-12-09 10:28:00     224.69    15498.0  United Kingdom    False
# 541715 2011-12-09 11:57:00      10.95    15311.0  United Kingdom    False
# 541716 2011-12-09 11:58:00       1.25    17315.0  United Kingdom    False
# 541717 2011-12-09 11:58:00       1.25    17315.0  United Kingdom    False
#
#         Cancellation  CustomerID_NA  Description_NA
# 141             True          False           False
# 154             True          False           False
# 235             True          False           False
# 236             True          False           False
# 237             True          False           False
# ...              ...            ...             ...
# 540449          True          False           False
# 541541          True          False           False
# 541715          True          False           False
# 541716          True          False           False
# 541717          True          False           False
#
# [10624 rows x 12 columns]

# %% [markdown]
# #### 2.1.2 Identify Negative Quantities that are NOT Cancellations

# %%
# check negative quantity for transactions that are not cancellations

noncancel_negquantity = negative_quantity.loc[~negative_quantity['InvoiceNo'].str.contains(r"^C", na=False)]

# transactions with negative quantities that are not cancellations
# lots of damages and adjustments

noncancel_negquantity['Description'].value_counts()
# Out:
# Description
# check                    120
# damages                   45
# damaged                   42
# ?                         41
# sold as set on dotcom     20
#                         ...
# lost??                     1
# wet                        1
# wet boxes                  1
# ????damages????            1
# lost                       1
# Name: count, Length: 138, dtype: int64

# %%
noncancel_negquantity['Description'].value_counts().index.tolist()
# Out:
# ['check',
#  'damages',
#  'damaged',
#  '?',
#  'sold as set on dotcom',
#  'Damaged',
#  'thrown away',
#  'Unsaleable, destroyed.',
#  '??',
#  'damages?',
#  'ebay',
#  'wet damaged',
#  'smashed',
#  'CHECK',
#  'missing',
#  'wet pallet',
#  'Dotcom sales',
#  'reverse 21/5/10 adjustment',
#  'mixed up',
#  'incorrect stock entry.',
#  'adjustment',
#  'wet rusty',
#  'counted',
#  'printing smudges/thrown away',
#  'crushed',
#  'wet/rusty',
#  'sold as 1',
#  '?missing',
#  'stock check',
#  'damages wax',
#  'dotcom',
#  '???missing',
#  'rusty throw away',
#  'faulty',
#  'Dotcom',
#  'Given away',
#  'mouldy, thrown away.',
#  'label mix up',
#  'showroom',
#  'MIA',
#  'samples/damages',
#  'incorrectly made-thrown away.',
#  'mystery! Only ever imported 1800',
#  'sold as 22467',
#  'cracked',
#  'sold in set?',
#  're dotcom quick fix.',
#  "Dotcom sold in 6's",
#  "thrown away-can't sell.",
#  "thrown away-can't sell",
#  'wrong code',
#  'adjust',
#  'POSSIBLE DAMAGES OR LOST?',
#  'MERCHANT CHANDLER CREDIT ERROR, STO',
#  'Display',
#  'Missing',
#  'wrong code?',
#  'DAMAGED',
#  'damaged stock',
#  'damages/display',
#  'broken',
#  'throw away',
#  'barcode problem',
#  '?lost',
#  'wrong barcode (22467)',
#  'wrong barcode',
#  'Amazon sold sets',
#  'dotcom sold sets',
#  'wrongly sold sets',
#  '? sold as sets?',
#  '?sold as sets?',
#  'Thrown away.',
#  'Dotcom set',
#  'wrongly sold as sets',
#  'Show Samples',
#  'found some more on shelf',
#  'Printing smudges/thrown away',
#  'sold as set by dotcom',
#  'sold as set on dotcom and amazon',
#  'water damage',
#  'incorrectly credited C550456 see 47',
#  'Water damaged',
#  'damages/dotcom?',
#  'reverse previous adjustment',
#  'damages/showroom etc',
#  'samples',
#  'damages/credits from ASOS.',
#  'Not rcvd in 10/11/2010 delivery',
#  'Thrown away-rusty',
#  'sold as set/6 by dotcom',
#  'temp adjustment',
#  'Crushed',
#  'crushed ctn',
#  '?display?',
#  'Dagamed',
#  'historic computer difference?....se',
#  'OOPS ! adjustment',
#  'mix up with c',
#  'Sold as 1 on dotcom',
#  'Damages/samples',
#  'code mix up? 84930',
#  'taig adjust no stock',
#  'stock creditted wrongly',
#  'incorrectly put back into stock',
#  'wrongly marked. 23343 in box',
#  'mouldy, unsaleable.',
#  '20713 wrongly marked',
#  'Wet pallet-thrown away',
#  'mouldy',
#  "can't find",
#  'crushed boxes',
#  'WET/MOULDY',
#  'Incorrect stock entry.',
#  'wrongly coded-23343',
#  'test',
#  'dotcom sales',
#  'Wrongly mrked had 85123a in box',
#  'Damages',
#  'wrongly coded 20713',
#  20713,
#  're-adjustment',
#  'Breakages',
#  'sold with wrong barcode',
#  '???lost',
#  'missing?',
#  'wrongly marked carton 22804',
#  'water damaged',
#  '?? missing',
#  '????missing',
#  'rusty thrown away',
#  'lost in space',
#  'wet?',
#  '???',
#  'lost??',
#  'wet',
#  'wet boxes',
#  '????damages????',
#  'lost']

# %%
a = df.loc[df['InvoiceNo'].str.startswith("A", na = False), :] # bad debt
b = df.loc[df['InvoiceNo'].str.startswith("C", na = False), :] # cancellations

# Summary

print(f"There are {a.shape[0]} fields with bad debt adjustments.")
print(f"There are {b.shape[0]} fields with cancellations.")
print(f"There are {noncancel_negquantity.shape[0]} fields with negative quantities that are not cancellations")
# Out:
# There are 3 fields with bad debt adjustments.
# There are 9288 fields with cancellations.
# There are 1336 fields with negative quantities that are not cancellations

# %% [markdown]
# #### 2.2 Check for UnitPrice = 0

# %%
df.loc[(df['UnitPrice'] == 0)]
# Out:
#        InvoiceNo StockCode                   Description  Quantity  \
# 622       536414     22139                           NaN        56
# 1970      536545     21134                           NaN         1
# 1971      536546     22145                           NaN         1
# 1972      536547     37509                           NaN         1
# 1987      536549    85226A                           NaN         1
# ...          ...       ...                           ...       ...
# 536981    581234     72817                           NaN        27
# 538504    581406    46000M  POLYESTER FILLER PAD 45x45cm       240
# 538505    581406    46000S  POLYESTER FILLER PAD 40x40cm       300
# 538554    581408     85175                           NaN        20
# 538919    581422     23169                       smashed      -235
#
#                InvoiceDate  UnitPrice CustomerID         Country  BadDebt  \
# 622    2010-12-01 11:52:00        0.0        NaN  United Kingdom    False
# 1970   2010-12-01 14:32:00        0.0        NaN  United Kingdom    False
# 1971   2010-12-01 14:33:00        0.0        NaN  United Kingdom    False
# 1972   2010-12-01 14:33:00        0.0        NaN  United Kingdom    False
# 1987   2010-12-01 14:34:00        0.0        NaN  United Kingdom    False
# ...                    ...        ...        ...             ...      ...
# 536981 2011-12-08 10:33:00        0.0        NaN  United Kingdom    False
# 538504 2011-12-08 13:58:00        0.0        NaN  United Kingdom    False
# 538505 2011-12-08 13:58:00        0.0        NaN  United Kingdom    False
# 538554 2011-12-08 14:06:00        0.0        NaN  United Kingdom    False
# 538919 2011-12-08 15:24:00        0.0        NaN  United Kingdom    False
#
#         Cancellation  CustomerID_NA  Description_NA
# 622            False           True            True
# 1970           False           True            True
# 1971           False           True            True
# 1972           False           True            True
# 1987           False           True            True
# ...              ...            ...             ...
# 536981         False           True            True
# 538504         False           True           False
# 538505         False           True           False
# 538554         False           True            True
# 538919         False           True           False
#
# [2515 rows x 12 columns]

# %%
print(df.loc[(df['UnitPrice'] == 0) & (df['CustomerID_NA'] == False)].shape[0])
print(df.loc[(df['UnitPrice'] == 0) & (df['Description_NA'] == False)].shape[0])

# Only 40 instances of UnitPrice == 0 occurs when CustomerID is not NA
# 1061 instances of UnitPrice == 0 occurs when Description is not NA
# Consider removing fields with UnitPrice == 0?
# Out:
# 40
# 1061

# %% [markdown]
# #### 2.3 Missing values

# %%
df.isnull().sum()

# large quantity of null values for 'Description' and 'CustomerID'
# Out:
# InvoiceNo            0
# StockCode            0
# Description       1454
# Quantity             0
# InvoiceDate          0
# UnitPrice            0
# CustomerID      135080
# Country              0
# BadDebt              0
# Cancellation         0
# dtype: int64

# %%
# # Investigate missing CustomerID

# Missing_CustomerID = data[data["CustomerID"].isna()]

# Missing_CustomerID.head()

# %%
# flag missing CustomerID and Description

df["CustomerID_NA"] = df["CustomerID"].isna()

df["Description_NA"] = df["Description"].isna()

df[["CustomerID_NA", "Description_NA"]]
# Out:
#         CustomerID_NA  Description_NA
# 0               False           False
# 1               False           False
# 2               False           False
# 3               False           False
# 4               False           False
# ...               ...             ...
# 541904          False           False
# 541905          False           False
# 541906          False           False
# 541907          False           False
# 541908          False           False
#
# [541909 rows x 2 columns]

# %%
df['Customer_ID_NA'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\jrroz\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Customer_ID_NA'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 df['Customer_ID_NA'].value_counts()
#
# File c:\Users\jrroz\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\jrroz\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Customer_ID_NA'

# %%
df['Description_NA'].value_counts()
# Out:
# Description_NA
# False    540455
# True       1454
# Name: count, dtype: int64

# %% [markdown]
# #### CustomerID analysis

# %%
df["CustomerID"].value_counts().reset_index()
# Out:
#       CustomerID  count
# 0        17841.0   7983
# 1        14911.0   5903
# 2        14096.0   5128
# 3        12748.0   4642
# 4        14606.0   2782
# ...          ...    ...
# 4367     17986.0      1
# 4368     13256.0      1
# 4369     18184.0      1
# 4370     13747.0      1
# 4371     15195.0      1
#
# [4372 rows x 2 columns]

# %%
mean = df["CustomerID"].value_counts().mean()
stddev = df["CustomerID"].value_counts().std()

print("Average orders per CustomerID:", mean, "\n" "Standard deviation: ", stddev)
# Out:
# Average orders per CustomerID: 93.05329368709972
# Standard deviation:  232.4716077416496
